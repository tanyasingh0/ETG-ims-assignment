# %%
record = {1001:{"Name":"Dairy Milk", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "chocolate"},
         1002:{"Name":"Kit Kat", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "chocolate"},
         1003:{"Name":"5 Star", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"10", "Type": "chocolate"},
         1004:{"Name":"Munch", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"5", "Type": "chocolate"},
         1005:{"Name":"Dairy Milk Silk", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"80", "Type": "chocolate"},
         1006:{"Name":"Bourbon", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1007:{"Name":"Hide & Seek", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1008:{"Name":"Parle G", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1009:{"Name":"Tiger Cream", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1010:{"Name":"Ferraro Rocher", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "chocolate"},
         1011:{"Name":"Milk Bikis", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1012:{"Name":"Melody", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"100", "Type": "chocolate"},
         1013:{"Name":"jimjam", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "biscuit"},
         1014:{"Name":"coke", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1015:{"Name":"mazza", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1016:{"Name":"frooti", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"10", "Type": "beverage"},
         1017:{"Name":"amul cool", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1018:{"Name":"sprite", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1019:{"Name":"coka cola", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1020:{"Name":"lassi", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1021:{"Name":"cream milk", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1022:{"Name":"limca", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "beverage"},
         1023:{"Name":"chocolate cake", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "cake"},
         1024:{"Name":"bikaji bhujiya", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"80", "Type": "namkeen"},
         1025:{"Name":"little hearts", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"10", "Type": "biscuit"},
         1026:{"Name":"choco roll", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"120", "Type": "cake"},
         1027:{"Name":"chips", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"20", "Type": "chips"},
         1028:{"Name":"banana chips", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"50", "Type": "chips"},
         1029:{"Name":"baked cookies", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"100", "Type": "biscuit"},
         1030:{"Name":"choco delight", "Exp":"sept 2022", "Mfd":"aug 2021", "Quantity":"100", "Price":"40", "Type": "chocolate"}}

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"1001": {"Name": "Dairy Milk", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "chocolate"}, "1002": {"Name": "Kit Kat", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "50", "Type": "chocolate"}, "1003": {"Name": "5 Star", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "10", "Type": "chocolate"}, "1004": {"Name": "Munch", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "5", "Type": "chocolate"}, "1005": {"Name": "Dairy Milk Silk", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "80", "Type": "chocolate"}, "1006": {"Name": "Bourbon", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1007": {"Name": "Hide & Seek", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1008": {"Name": "Parle G", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1009":
# ...

# %%
fd = open("record.json", 'w')
fd.write(js)
fd.close()

# %%
fd = open("record.json",'r')
txt = fd.read()
fd.close()

# %%
txt
# Out:
# '{"1001": {"Name": "Dairy Milk", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "chocolate"}, "1002": {"Name": "Kit Kat", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "50", "Type": "chocolate"}, "1003": {"Name": "5 Star", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "10", "Type": "chocolate"}, "1004": {"Name": "Munch", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "5", "Type": "chocolate"}, "1005": {"Name": "Dairy Milk Silk", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "80", "Type": "chocolate"}, "1006": {"Name": "Bourbon", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1007": {"Name": "Hide & Seek", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1008": {"Name": "Parle G", "Exp": "sept 2022", "Mfd": "aug 2021", "Quantity": "100", "Price": "40", "Type": "biscuit"}, "1009":
# ...

# %%
record =json.loads(txt)

# %%
details = open("record.json",'r')
txt = details.read()
details.close()

ID={}
Quantity={}
Price={}
Type={}

cart=[]

c="y" 

print("Welcome to IMS")
print()
print("A-Add an item")
print("R-Remove an item")
print("E-Edit specifics of an item")
print("L-List all items")
print("I-Inquire about a part")
print("P-Purchase")
print("C-Checkout")
print("S-Show all parts purchased")
print("Q-Quit")
print("remove-Remove an item from the cart")
print("help-See all commands again")
print()


total_cost=0 
flag=0 

while(c!= "q" or c!= "Q"):
    c= input("What would you like to do? ")
    
    if(c=="q" or c=="Q"):
        break
        
    elif(c=="A" or c=="a"):
        ID = int(input("Enter product id: "))
        Price = float(input("Enter product price: "))
        Type = input("Enter product type: ")
        Quantity = int(input("Enter product quantity: "))
        
        m=0
        for i in range(0,len(Price)):
            if(ID in Price):
                ID+=1
                m=1
        if(m==1):
            print()
            print("That part number already exists :(, changing value to ",ID)
                
        Price.update({ID: Price})
        Type.update({ID: Type})
        if(Quantity > -1):
            Quantity.update({ID: Quantity})
        else:
            Quantity = 0
            Quantity.update({ID: Quantity})
            print("The stock of an item cannot be negative, the stock has been set to 0.")
        print()
        print("Product ID : ",ID," Type: ",Type.get(ID)," Price: ",Price.get(ID)," Quantity: ",Quantity.get(ID))
        print("Product was added successfully!")
        print()
        
    elif(c=="E" or c=="e"):
        print()
        ID = int(input("Enter Product ID: "))
        if(ID in Price):
            Price = float(input("Enter Product price: "))
            Type = input("Enter Product Type: ")
            Quantity = int(input("Enter Product Quantity: "))
                
            Price.update({ID : Price})
            Type.update({ID : Type})
            Quantity.update({ID : Quantity})
            
        else:
            print("That item does not exist, to add an item use a")
        print()
    
            
    elif(c=="R" or c=="r"):
        print()
        ID = int(input("Enter Product ID: "))
        if(ID in Price):
            are_you_sure = input("Are you sure you want to remove that item(y/n)? ")
            if(are_you_sure=="y" or are_you_sure=="Y"):
                Price.pop(ID)
                Type.pop(ID)
                Quantity.pop(ID)
                print("Item successfully removed!")
            print()
        else:
            print("Sorry, we don't have such an item!")
            print()
        
    elif(c=="L" or c=="l"):
        print()
        print("Parts and their prices: ",Price)
        print("Type of product: ",Type)
        print("Quantity left of Item: ",Quantity)
        print()

    elif(c=="I" or c=="i"):
        print()
        ID=int(input("Enter Product ID: "))
        if(ID in Price):
            print()
            print("Product ID : ",ID," Type : ",Type.get(ID)," Price: ",Price.get(ID)," Quantity: ",Quantity.get(ID))
            if(Quantity.get(ID)<3 and Quantity.get(ID)!=0):
                print("Only ",Quantity.get(ID)," remaining! Hurry!")
            print()
        else:
            print("Sorry we don't have such an item!")
            print()
        
    elif(c=="P" or c=="p"):
        print()
        ID = int(input("Enter Part number: "))
        if(ID in Price):
            if(flag==1):
                flag=0
            Quantity_current = Quantity.get(ID)
            if(Quantity_current>0):
                Quantity_current = Quantity.get(ID)
                Quantity[ID] = Quantity_current-1
                item_price = Price.get(ID)
                total_cost = total_cost+item_price
                print(description.get(p_no),"added to cart: ","Rs",item_price)
                cart.append(p_no)
            else:
                print("Sorry! We don't have that item in stock!")
        else:
                print("Sorry! We don't have such an item!")
        print()
        
    elif(c=="C" or c=="c"):
        print()
        print("You bought the following parts: ",cart)
        print("Total: ","Rs",round(total_cost,2))
        tax= round(0.06*total_cost,2)
        print("Tax is 6%: ","Rs",tax)
        total = round(total_cost+tax,2)
        print("After Tax: ","Rs",total)
        total_cost=0
        flag=1
        print()
        print("You can still purchase items after check out, your cart has been reset. To quit press q")
        print()
        
    elif(c=="help"):
        print()
        print("Help Centre")
        print("A-Add an item")
        print("R-Remove an item")
        print("E-Edit specifics of an item")
        print("L-List all items")
        print("I-Inquire about a part")
        print("P-Purchase")
        print("C-Checkout")
        print("S-Show all parts purchased")
        print("remove-Remove an item from the cart")
        print("help-See all commands again")
        print("If you have any other questions or concerns please contact the manager.")
        print()
        
    elif(c=="remove" or c=="Remove"):
        print()
        are_you_sure = input("Are you sure you want to remove an item from the cart(y/n)? ")
        if(are_you_sure=="y"):
            p_no = int(input("Enter part number to remove from cart: "))
            if(ID in cart):
                Quantity_current = Quantity.get(ID)
                Quantity[ID] = Quantity_current+1
                item_price = Price.get(p_no)
                total_cost = total_cost-item_price
                j=0
                for i in range(0,len(cart)):
                    if(i==p_no):
                        j=i

                cart.pop(j)
                print(Type.get(ID),"removed from cart: ")
                print()
            else:
                print()
                print("That item is not in your cart!")
                print()
                
    elif(c=="s" or c=="S"):
        print()
        print(cart)
        print()
        
    else:
        print()
        print("ERROR! Contact Company for help!")
        print()


if(total_cost>0 and flag==0):
    print()
    print("You bought: ",cart)
    print("Total: ","rs",round(total_cost,2))
    tax= round(0.06*total_cost,2)
    print("Tax is 6%: ","rs",tax)
    total = round(total_cost+tax,2)
    print("After Tax: ","rs",total)
    
print()
print("Thank you for using IMS")

details = open("stock.txt","w")
no_items=len(Price)
details.write(str(no_items)+"\n")
for i in range(0,no_items):
    details.write(str(i+1)+","+str(Price[i+1])+"\n")
    
for i in range(0,no_items):
    details.write(str(i+1)+","+Type[i+1]+"\n")
    
for i in range(0,no_items):
    details.write(str(i+1)+","+str(Quantity[i+1])+"\n")
    
details.close()
# Out:
# Welcome to IMS
#
# A-Add an item
# R-Remove an item
# E-Edit specifics of an item
# L-List all items
# I-Inquire about a part
# P-Purchase
# C-Checkout
# S-Show all parts purchased
# Q-Quit
# remove-Remove an item from the cart
# help-See all commands again
